# %%
# %matplotlib notebook
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from model import visutils
from model.selectpoints import select_k_points

# %%
pts = []
for i in range(3,5):
    fig = plt.figure()
    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    img1 = plt.imread(f"./model/dtu_data/object/{i}.png")
    img2 = plt.imread(f"./model/dtu_data/object/{i+1}.png")
    ax1.imshow(img1)
    ax2.imshow(img2)
    pts1 = select_k_points(ax1, 3)
    pts2 = select_k_points(ax2, 3)
    pts.append([[pts1.xs, pts1.ys],[pts2.xs, pts2.ys]])
    plt.show()

# %%
import numpy as np
pts = np.array(pts)
print(pts.shape)

# %%
import numpy as np
pts = np.array(pts)
print(pts.shape)
# Out:
# (2, 2, 2, 3)

# %%
point_cloud = torch.load("point_cloud.txt")
mesh = torch.load("mesh.txt")

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection='3d')
# ax.plot(point_cloud[0].detach().cpu(), point_cloud[1].detach().cpu(), point_cloud[2].detach().cpu(), 'r.')
ax.plot_trisurf(point_cloud[0, :].detach().cpu(),
                point_cloud[1, :].detach().cpu(),
                point_cloud[2, :].detach().cpu(),
                triangles=mesh.detach().cpu(),
                antialiased=False)
ax.view_init(azim=90, elev=-90)  #set the camera viewpointn
visutils.set_axes_equal_3d(ax)
visutils.label_axes(ax)
plt.title('Final Mesh View 1')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <div id='117671c5-fe28-47f9-b8a1-35a1d610b316'></div>
